# %%
import pandas as pd
url = "https://gist.githubusercontent.com/tgcsantos/3bdb29eba6ce391e90df2b72205ba891/raw/22fa920e80c9fa209a9fccc8b52d74cc95d1599b/dados_imoveis.csv"
dados = pd.read_csv(url)

# %%
dados.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor
# 0        4          8      6  R$ 7.000.000
# 1        4          4      4  R$ 3.700.000
# 2        4          3      2    R$ 380.000
# 3        3          2      4    R$ 685.000
# 4        3          2      2    R$ 540.000

# %%
dados.sample(10)
# Out:
#                                 Rua                 Bairro     Cidade  \
# 6999               Rua Rocha Galvão       Jardim da Glória  São Paulo
# 6949       Rua Ferreira do Alentejo       Jardim Caravelas  São Paulo
# 8698                            NaN     Vila Regente Feijó  São Paulo
# 6522  Rua Doutor Sales Gomes Júnior       Vila Paulo Silas  São Paulo
# 4342             Rua Cayowaá, 1755                  Sumaré  São Paulo
# 4790                            NaN        Jardim Paulista  São Paulo
# 302                 Rua Teviot, 50     Vila Nova Conceição  São Paulo
# 255          Rua Maestro Elias Lobo        Jardim Paulista  São Paulo
# 7213                            NaN  Vila Brasílio Machado  São Paulo
# 2986            Rua Francisco Farel   Jardim das Bandeiras  São Paulo
#
#       Metragem  Quartos  Banheiros  Vagas         Valor
# 6999       305        3          3      4  R$ 1.085.000
# 6949       240        4          4      3  R$ 1.535.000
# 8698       193        2          1      2    R$ 500.000
# 6522        90        3          2      2    R$ 550.000
# 4342       131        3          3      1    R$ 990.000
# 4790       360        3          5      3  R$ 3.990.000
# 302        120        2          2      2  R$ 1.620.000
# 255        191        3          4      1  R$ 2.590.000
# 7213       116        3          1      2    R$ 680.000
# 2986       315        3          3      3  R$ 3.160.000

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10008 entries, 0 to 10007
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Rua        6574 non-null   object
#  1   Bairro     9996 non-null   object
#  2   Cidade     10008 non-null  object
#  3   Metragem   10008 non-null  int64
#  4   Quartos    10008 non-null  int64
#  5   Banheiros  10008 non-null  int64
#  6   Vagas      10008 non-null  int64
#  7   Valor      10008 non-null  object
# dtypes: int64(4), object(4)
# memory usage: 625.6+ KB

# %%
dados["Bairro"][6522]
# Out:
# 'Vila Paulo Silas'

# %%
dados.Metragem.mean()
# Out:
# 442.30065947242207

# %%
dados["Metragem"].mean()
# Out:
# 442.30065947242207

# %%
sum((dados["Bairro"] == "Vila Mariana"))
# Out:
# 184

# %%
tem_imoveis_vila =( dados["Bairro"] == "Vila Mariana")
tem_imoveis_vila
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10003    False
# 10004    False
# 10005    False
# 10006    False
# 10007    False
# Name: Bairro, Length: 10008, dtype: bool

# %%
imoveis_vila_mariana = dados[tem_imoveis_vila]
imoveis_vila_mariana
# Out:
#                                Rua        Bairro     Cidade  Metragem  \
# 100               Rua Pero Correia  Vila Mariana  São Paulo       250
# 120   Praça Doutor Carvalho Franco  Vila Mariana  São Paulo       250
# 155     Rua Professor João Marinho  Vila Mariana  São Paulo       170
# 160                            NaN  Vila Mariana  São Paulo       228
# 334         Rua Pero Correia, 892   Vila Mariana  São Paulo       350
# ...                            ...           ...        ...       ...
# 9645               Rua Sousa Ramos  Vila Mariana  São Paulo       285
# 9701             Rua Benito Juarez  Vila Mariana  São Paulo       171
# 9737             Rua Benito Juarez  Vila Mariana  São Paulo       171
# 9807                           NaN  Vila Mariana  São Paulo       275
# 9852              Rua França Pinto  Vila Mariana  São Paulo       280
#
#       Quartos  Banheiros  Vagas         Valor
# 100         3          3      1  R$ 1.350.000
# 120         3          5      2  R$ 2.450.000
# 155         3          4      2  R$ 1.490.000
# 160         4          5      3  R$ 2.200.000
# 334         6          4     10  R$ 1.700.000
# ...       ...        ...    ...           ...
# 9645        3          5      5  R$ 1.650.000
# 9701        3          2      4  R$ 1.650.000
# 9737        3          2      4  R$ 1.650.000
# 9807        3          1      6  R$ 1.500.000
# 9852        3          3      4  R$ 1.600.000
#
# [184 rows x 8 columns]

# %%
imoveis_vila_mariana["Metragem"].mean()
# Out:
# 233.6195652173913

# %%
dados["Bairro"].value_counts()
# Out:
# Alto de Pinheiros     409
# Jardim Guedala        403
# Jardim Paulista       309
# Brooklin Paulista     247
# Jardim Europa         240
#                      ...
# Jardim das Imbuias      1
# Vila Represa            1
# Vila Nancy              1
# Sítio Represa           1
# Vila Invernada          1
# Name: Bairro, Length: 701, dtype: int64

# %%
n_imoveis_bairro = dados["Bairro"].value_counts()
n_imoveis_bairro.head(10).plot.bar()

# %% [markdown]
# Desafios:
#
# 1 - Realizar a média da metragem para cara um dos bairros (Paulo)
#
# 2 - 2 formas de selecionar os dados por bairro (consultar os métodos na documentação do pandas) (Thiago)
#
# 3 - Explorar alguns gráficos na documentação e aplicar nas demais colunas do DF, tentar colocar alguma conclusão (Thiago)
#
# 4 - Pegar outros estatísticas dos dados, média, mediana, mim, max (Vivi)
#
# 5 - Descobrir quais são os bairros que não tem nome de Rua. (Vivi)

# %%
# 1. Realizar a média da metragem para cara um dos bairros
aux = dados.groupby("Bairro")
aux["Metragem"].mean()

# OBS:groupby = Agrupe DataFrame usando um mapeador ou por uma série de colunas.
# OBS1:mean = Retorna a média dos valores sobre o eixo solicitado.
# Out:
# Bairro
# Aclimação            253.056818
# Alto da Boa Vista    418.875000
# Alto da Lapa         294.337209
# Alto da Mooca        270.050000
# Alto de Pinheiros    433.444988
#                         ...
# Vila Água Funda      152.200000
# Água Branca          191.000000
# Água Fria            165.416667
# Água Funda           139.000000
# Água Rasa            340.250000
# Name: Metragem, Length: 701, dtype: float64

# %%
# 1. Realizar a média da metragem para cara um dos bairros
aux = dados.groupby("Bairro")
aux["Metragem"].describe()

# OBS:groupby = Agrupe DataFrame usando um mapeador ou por uma série de colunas.
# OBS1:describe = Gerar estatísticas descritivas.
# Out:
#                    count        mean         std    min     25%    50%  \
# Bairro
# Aclimação           88.0  253.056818  159.140245  104.0  165.00  227.5
# Alto da Boa Vista    8.0  418.875000  111.880596  315.0  347.50  378.0
# Alto da Lapa        86.0  294.337209  187.674036   46.0  151.25  255.0
# Alto da Mooca       20.0  270.050000  237.306924   84.0  133.75  182.5
# Alto de Pinheiros  409.0  433.444988  145.676574  100.0  344.00  412.0
# ...                  ...         ...         ...    ...     ...    ...
# Vila Água Funda      5.0  152.200000   44.353128   90.0  138.00  143.0
# Água Branca         13.0  191.000000   91.045776   91.0  143.00  174.0
# Água Fria           12.0  165.416667   82.934211   60.0   76.25  174.5
# Água Funda           2.0  139.000000   19.798990  125.0  132.00  139.0
# Água Rasa            8.0  340.250000  294.046036   86.0  172.50  180.0
#
#                       75%     max
# Bairro
# Aclimação          300.00  1500.0
# Alto da Boa Vista  448.75   595.0
# Alto da Lapa       363.75  1133.0
# Alto da Mooca      221.25   805.0
# Alto de Pinheiros  505.00  1530.0
# ...                   ...     ...
# Vila Água Funda    190.00   200.0
# Água Branca        200.00   400.0
# Água Fria          210.50   314.0
# Água Funda         146.00   153.0
# Água Rasa          455.75   805.0
#
# [701 rows x 8 columns]

# %%
# 2. Formas de selecionar os dados por bairro
aux = dados.groupby("Bairro")
aux.mean()
# Out:
#                      Metragem   Quartos  Banheiros     Vagas
# Bairro
# Aclimação          253.056818  3.318182   3.079545  2.909091
# Alto da Boa Vista  418.875000  4.125000   5.125000  4.625000
# Alto da Lapa       294.337209  3.151163   3.790698  3.906977
# Alto da Mooca      270.050000  3.300000   2.600000  3.650000
# Alto de Pinheiros  433.444988  3.938875   4.838631  5.004890
# ...                       ...       ...        ...       ...
# Vila Água Funda    152.200000  2.600000   2.200000  2.600000
# Água Branca        191.000000  3.153846   3.076923  2.461538
# Água Fria          165.416667  2.833333   3.416667  2.500000
# Água Funda         139.000000  3.000000   2.500000  2.000000
# Água Rasa          340.250000  3.500000   3.250000  5.250000
#
# [701 rows x 4 columns]

# %%
# 2. Formas de selecionar os dados por bairro
aux = dados[dados['Bairro'] == 'Aclimação']
aux
# Out:
#                                              Rua     Bairro     Cidade  \
# 269                              Rua Ximbó, 410   Aclimação  São Paulo
# 670                          Rua Alabastro, 151   Aclimação  São Paulo
# 1265                           Rua Carlos Chagas  Aclimação  São Paulo
# 1287                        Rua Doutor João Maia  Aclimação  São Paulo
# 1347                        Rua Doutor João Maia  Aclimação  São Paulo
# ...                                          ...        ...        ...
# 9260  Rua Doutor Rafael Caramuru Lanzelloti, 77   Aclimação  São Paulo
# 9366                                Rua Baturité  Aclimação  São Paulo
# 9418                           Rua André Gouveia  Aclimação  São Paulo
# 9539                                    Rua Rubi  Aclimação  São Paulo
# 9776                       Rua Oscar Guanabarino  Aclimação  São Paulo
#
#       Metragem  Quartos  Banheiros  Vagas  \
# 269        140        4          3      4
# 670        129        3          2      3
# 1265       280        3          2      2
# 1287       380        3          5      2
# 1347       385        3          5      2
# ...        ...      ...        ...    ...
# 9260       120        3          2      1
# 9366       156        3          4      1
# 9418       199        3          4      3
# 9539      1500        4          2      6
# 9776       300        3          3      3
#
#                                      Valor
# 269                             R$ 800.000
# 670                             R$ 960.000
# 1265                          R$ 2.200.000
# 1287                          R$ 2.660.000
# 1347                          R$ 2.660.000
# ...                                    ...
# 9260                            R$ 900.001
# 9366                            R$ 800.000
# 9418                          R$ 1.930.000
# 9539                          R$ 5.000.000
# 9776  R$ 7.000\n                      /Mês
#
# [88 rows x 8 columns]

# %%
#3. Explorar alguns gráficos na documentação e aplicar nas demais colunas do DF
dados[["Bairro","Quartos","Banheiros"]].sample(12).groupby("Bairro").mean().plot.line()

# %%
##3. Explorar alguns gráficos na documentação e aplicar nas demais colunas do DF
dados[["Bairro","Quartos","Banheiros"]].sample(10).groupby("Bairro").max().plot.bar()

# %%
#4. Pegar outros estatísticas dos dados, média, mediana, mim, max
dados["Metragem"].mean(), dados["Metragem"].median(), dados["Metragem"].min(), dados["Metragem"].max()
# Out:
# (442.30065947242207, 290.0, 10, 750000)

# %%
#4. Pegar outros estatísticas dos dados, média, mediana, mim, max
dados["Quartos"].describe()
# Out:
# count    10008.000000
# mean         3.483114
# std          1.064200
# min          1.000000
# 25%          3.000000
# 50%          3.000000
# 75%          4.000000
# max         16.000000
# Name: Quartos, dtype: float64

# %%
#4. Pegar outros estatísticas dos dados, média, mediana, mim, max
dados["Metragem"].describe()
# Out:
# count     10008.000000
# mean        442.300659
# std        7515.379389
# min          10.000000
# 25%         173.000000
# 50%         290.000000
# 75%         460.250000
# max      750000.000000
# Name: Metragem, dtype: float64

# %%
#5. Descobrir quais são os bairros que não tem nome de Rua
dados[dados["Rua"].isna()].describe()
# Out:
#            Metragem      Quartos    Banheiros        Vagas
# count   3434.000000  3434.000000  3434.000000  3434.000000
# mean     415.965929     3.580664     4.110367     4.514269
# std      660.586487     1.059290     2.210926     3.137578
# min       35.000000     1.000000     1.000000     1.000000
# 25%      198.000000     3.000000     3.000000     3.000000
# 50%      353.000000     4.000000     4.000000     4.000000
# 75%      539.750000     4.000000     5.000000     6.000000
# max    35677.000000    13.000000    40.000000    42.000000

# %%
#5. Descobrir quais são os bairros que não tem nome de Rua
dados[dados["Rua"].isna()].groupby("Bairro")["Bairro"].unique().values
# Out:
# array([array(['Aclimação'], dtype=object),
#        array(['Alto da Boa Vista'], dtype=object),
#        array(['Alto da Lapa'], dtype=object),
#        array(['Alto da Mooca'], dtype=object),
#        array(['Alto de Pinheiros'], dtype=object),
#        array(['Aricanduva'], dtype=object),
#        array(['Barra Funda'], dtype=object),
#        array(['Bela Aliança'], dtype=object),
#        array(['Belenzinho'], dtype=object),
#        array(['Boaçava'], dtype=object),
#        array(['Bosque da Saúde'], dtype=object),
#        array(['Brasilândia'], dtype=object),
#        array(['Brooklin'], dtype=object),
#        array(['Brooklin Novo'], dtype=object),
#        array(['Brooklin Paulista'], dtype=object),
#        array(['Brás'], dtype=object),
#        array(['Burgo Paulista'], dtype=object),
#        array(['Butantã'], dtype=object), array(['Cambuci'], dtype=object),
#        array(['Campininha'], dtype=object),
#        array(['Campo Belo'], dtype=object),
#        array(['Capão Redondo'], dtype=object),
#        array(['Caxingui'], dtype=object),
#        array(['Cerqueira César'], dtype=object),
#        array(['Chora Menino'], dtype=object),
#        array(['Chácara Belenzinho'], dtype=object),
#        array(['Chácara Califórnia'], dtype=object),
#        array(['Chácara Flora'], dtype=object),
#        array(['Chácara Inglesa'], dtype=object),
#        array(['Chácara Japonesa'], dtype=object),
#        array(['Chácara Mafalda'], dtype=object),
#        array(['Chácara Meyer'], dtype=object),
#        array(['Chácara Monte Alegre'], dtype=object),
#        array(['Chácara Santo Antônio (Zona Sul)'], dtype=object),
#        array(['Chácara Tatuapé'], dtype=object),
#        array(['Cidade Ademar'], dtype=object),
#        array(['Cidade Antônio Estevão de Carvalho'], dtype=object),
#        array(['Cidade Centenário'], dtype=object),
#        array(['Cidade Domitila'], dtype=object),
#        array(['Cidade Dutra'], dtype=object),
#        array(['Cidade Jardim'], dtype=object),
#        array(['Cidade Monções'], dtype=object),
#        array(['Cidade Mãe do Céu'], dtype=object),
#        array(['Cidade Patriarca'], dtype=object),
#        array(['Cidade São Mateus'], dtype=object),
#        array(['Cidade Vargas'], dtype=object),
#        array(['City América'], dtype=object),
#        array(['Conjunto Habitacional Castro Alves'], dtype=object),
#        array(['Conjunto Residencial Butantã'], dtype=object),
#        array(['Conjunto Residencial Morada do Sol'], dtype=object),
#        array(['Conjunto Residencial Vista Verde'], dtype=object),
#        array(['Consolação'], dtype=object),
#        array(['Cupecê'], dtype=object),
#        array(['Engenheiro Goulart'], dtype=object),
#        array(['Fazenda Morumbi'], dtype=object),
#        array(['Ferreira'], dtype=object),
#        array(['Granja Julieta'], dtype=object),
#        array(['Higienópolis'], dtype=object),
#        array(['Indianópolis'], dtype=object),
#        array(['Instituto de Previdência'], dtype=object),
#        array(['Interlagos'], dtype=object),
#        array(['Ipiranga'], dtype=object),
#        array(['Itaberaba'], dtype=object),
#        array(['Itaim Bibi'], dtype=object),
#        array(['Itaquera'], dtype=object),
#        array(['Jabaquara'], dtype=object),
#        array(['Jaguaré'], dtype=object), array(['Jaraguá'], dtype=object),
#        array(['Jardim Aeroporto'], dtype=object),
#        array(['Jardim Ampliação'], dtype=object),
#        array(['Jardim Amália'], dtype=object),
#        array(['Jardim América'], dtype=object),
#        array(['Jardim Ana Maria'], dtype=object),
#        array(['Jardim Analia Franco'], dtype=object),
#        array(['Jardim Anália Franco'], dtype=object),
#        array(['Jardim Boa Vista (Zona Oeste)'], dtype=object),
#        array(['Jardim Bonfiglioli'], dtype=object),
#        array(['Jardim Brasil (Zona Sul)'], dtype=object),
#        array(['Jardim Brasília (Zona Leste)'], dtype=object),
#        array(['Jardim Bélgica'], dtype=object),
#        array(['Jardim Camargo Novo'], dtype=object),
#        array(['Jardim Campo Grande'], dtype=object),
#        array(['Jardim Castelo'], dtype=object),
#        array(['Jardim Celeste'], dtype=object),
#        array(['Jardim Cidade Pirituba'], dtype=object),
#        array(['Jardim Cidalia'], dtype=object),
#        array(['Jardim Cidália'], dtype=object),
#        array(['Jardim Coimbra'], dtype=object),
#        array(['Jardim Colombo'], dtype=object),
#        array(['Jardim Consórcio'], dtype=object),
#        array(['Jardim Cordeiro'], dtype=object),
#        array(['Jardim Célia (Zona Sul)'], dtype=object),
#        array(["Jardim D'Abril"], dtype=object),
#        array(['Jardim Danfer'], dtype=object),
#        array(['Jardim Dom Bosco'], dtype=object),
#        array(['Jardim Eliana'], dtype=object),
#        array(['Jardim Ernestina'], dtype=object),
#        array(['Jardim Ester'], dtype=object),
#        array(['Jardim Ester Yolanda'], dtype=object),
#        array(['Jardim Europa'], dtype=object),
#        array(['Jardim Everest'], dtype=object),
#        array(['Jardim Floresta'], dtype=object),
#        array(['Jardim Franca'], dtype=object),
#        array(['Jardim Gonzaga'], dtype=object),
#        array(['Jardim Guanca'], dtype=object),
#        array(['Jardim Guarau'], dtype=object),
#        array(['Jardim Guedala'], dtype=object),
#        array(['Jardim Heliomar'], dtype=object),
#        array(['Jardim Hípico'], dtype=object),
#        array(['Jardim Independência'], dtype=object),
#        array(['Jardim Itacolomi'], dtype=object),
#        array(['Jardim Jabaquara'], dtype=object),
#        array(['Jardim Japão'], dtype=object),
#        array(['Jardim Jussara'], dtype=object),
#        array(['Jardim Leonor'], dtype=object),
#        array(['Jardim Leonor Mendes de Barros'], dtype=object),
#        array(['Jardim Londrina'], dtype=object),
#        array(['Jardim Luzitânia'], dtype=object),
#        array(['Jardim Marajoara'], dtype=object),
#        array(['Jardim Maria Duarte'], dtype=object),
#        array(['Jardim Maria Estela'], dtype=object),
#        array(['Jardim Marília'], dtype=object),
#        array(['Jardim Miriam'], dtype=object),
#        array(['Jardim Monte Alegre'], dtype=object),
#        array(['Jardim Monte Kemel'], dtype=object),
#        array(['Jardim Morro Verde'], dtype=object),
#        array(['Jardim Morumbi'], dtype=object),
#        array(['Jardim Nice'], dtype=object),
#        array(['Jardim Novo Mundo'], dtype=object),
#        array(['Jardim Palmares (Zona Sul)'], dtype=object),
#        array(['Jardim Panorama'], dtype=object),
#        array(["Jardim Panorama D'Oeste"], dtype=object),
#        array(['Jardim Patente'], dtype=object),
#        array(['Jardim Patente Novo'], dtype=object),
#        array(['Jardim Paulista'], dtype=object),
#        array(['Jardim Paulistano'], dtype=object),
#        array(['Jardim Peri'], dtype=object),
#        array(['Jardim Petropolis'], dtype=object),
#        array(['Jardim Petrópolis'], dtype=object),
#        array(['Jardim Pirituba'], dtype=object),
#        array(['Jardim Planalto'], dtype=object),
#        array(['Jardim Ponte Rasa'], dtype=object),
#        array(['Jardim Prudência'], dtype=object),
#        array(['Jardim Rincão'], dtype=object),
#        array(['Jardim Rizzo'], dtype=object),
#        array(['Jardim Sabará'], dtype=object),
#        array(['Jardim Santa Cruz (Campo Grande)'], dtype=object),
#        array(['Jardim Santa Helena'], dtype=object),
#        array(['Jardim Santa Maria'], dtype=object),
#        array(['Jardim Santo Amaro'], dtype=object),
#        array(['Jardim Santo Elias'], dtype=object),
#        array(['Jardim Sarah'], dtype=object),
#        array(['Jardim Satélite'], dtype=object),
#        array(['Jardim Sul São Paulo'], dtype=object),
#        array(['Jardim São Carlos (Zona Sul)'], dtype=object),
#        array(['Jardim Sílvia (Zona Oeste)'], dtype=object),
#        array(['Jardim Taboão'], dtype=object),
#        array(['Jardim Teresa'], dtype=object),
#        array(['Jardim Textil'], dtype=object),
#        array(['Jardim Tremembe'], dtype=object),
#        array(['Jardim Triana'], dtype=object),
#        array(['Jardim Trussardi'], dtype=object),
#        array(['Jardim Umuarama'], dtype=object),
#        array(['Jardim Vergueiro (Sacomã)'], dtype=object),
#        array(['Jardim Viana'], dtype=object),
#        array(['Jardim Vila Carrão'], dtype=object),
#        array(['Jardim Vila Formosa'], dtype=object),
#        array(['Jardim Vila Mariana'], dtype=object),
#        array(['Jardim Virginia Bianca'], dtype=object),
#        array(['Jardim Vitória Régia'], dtype=object),
#        array(['Jardim Vivan'], dtype=object),
#        array(['Jardim da Glória'], dtype=object),
#        array(['Jardim da Saúde'], dtype=object),
#        array(['Jardim das Acácias'], dtype=object),
#        array(['Jardim das Bandeiras'], dtype=object),
#        array(['Jardim das Camélias'], dtype=object),
#        array(['Jardim das Vertentes'], dtype=object),
#        array(['Jardim do Colégio (Zona Norte)'], dtype=object),
#        array(['Jardim dos Estados'], dtype=object),
#        array(['Lapa'], dtype=object),
#        array(['Lapa de Baixo'], dtype=object),
#        array(['Lar São Paulo'], dtype=object),
#        array(['Lauzane Paulista'], dtype=object),
#        array(['Liberdade'], dtype=object),
#        array(['Mirandópolis'], dtype=object),
#        array(['Moema'], dtype=object), array(['Mooca'], dtype=object),
#        array(['Morumbi'], dtype=object),
#        array(['Nova Piraju'], dtype=object),
#        array(['Pacaembu'], dtype=object),
#        array(['Paineiras do Morumbi'], dtype=object),
#        array(['Parada XV de Novembro'], dtype=object),
#        array(['Paraisópolis'], dtype=object),
#        array(['Paraíso'], dtype=object),
#        array(['Paraíso do Morumbi'], dtype=object),
#        array(['Parque Alves de Lima'], dtype=object),
#        array(['Parque Boturussu'], dtype=object),
#        array(['Parque Casa de Pedra'], dtype=object),
#        array(['Parque Colonial'], dtype=object),
#        array(['Parque Continental'], dtype=object),
#        array(['Parque Edu Chaves'], dtype=object),
#        array(['Parque Guarani'], dtype=object),
#        array(['Parque Imperial'], dtype=object),
#        array(['Parque Jabaquara'], dtype=object),
#        array(['Parque Mandaqui'], dtype=object),
#        array(['Parque Maria Domitila'], dtype=object),
#        array(['Parque Monteiro Soares'], dtype=object),
#        array(['Parque Nações Unidas'], dtype=object),
#        array(['Parque Novo Mundo'], dtype=object),
#        array(['Parque Peruche'], dtype=object),
#        array(['Parque Residencial Oratorio'], dtype=object),
#        array(['Parque Santa Rita'], dtype=object),
#        array(['Parque Santo Antônio (Aricanduva)'], dtype=object),
#        array(['Parque Savoy City'], dtype=object),
#        array(['Parque São Domingos'], dtype=object),
#        array(['Parque São Lucas'], dtype=object),
#        array(['Parque São Rafael'], dtype=object),
#        array(['Parque da Lapa'], dtype=object),
#        array(['Parque da Mooca'], dtype=object),
#        array(['Parque da Vila Prudente'], dtype=object),
#        array(['Parque dos Príncipes'], dtype=object),
#        array(['Penha de França'], dtype=object),
#        array(['Perdizes'], dtype=object),
#        array(['Pinheiros'], dtype=object),
#        array(['Planalto Paulista'], dtype=object),
#        array(['Praia Paulistinha'], dtype=object),
#        array(['Quinta da Paineira'], dtype=object),
#        array(['Real Parque'], dtype=object),
#        array(['Retiro Morumbi'], dtype=object),
#        array(['Rio Pequeno'], dtype=object),
#        array(['Sacomã'], dtype=object),
#        array(['Santa Cecília'], dtype=object),
#        array(['Santana'], dtype=object),
#        array(['Santo Amaro'], dtype=object),
#        array(['Saúde'], dtype=object), array(['Siciliano'], dtype=object),
#        array(['Sumarezinho'], dtype=object),
#        array(['Sumaré'], dtype=object),
#        array(['Super Quadra Morumbi'], dtype=object),
#        array(['Sítio do Mandaqui'], dtype=object),
#        array(['Tatuapé'], dtype=object),
#        array(['Tremembé'], dtype=object),
#        array(['Tucuruvi'], dtype=object),
#        array(['Vila Adalgisa'], dtype=object),
#        array(['Vila Agueda'], dtype=object),
#        array(['Vila Albertina'], dtype=object),
#        array(['Vila Alexandria'], dtype=object),
#        array(['Vila Alpina'], dtype=object),
#        array(['Vila América'], dtype=object),
#        array(['Vila Analia'], dtype=object),
#        array(['Vila Andrade'], dtype=object),
#        array(['Vila Anglo Brasileira'], dtype=object),
#        array(['Vila Anhangüera'], dtype=object),
#        array(['Vila Antonieta'], dtype=object),
#        array(['Vila Antonina'], dtype=object),
#        array(['Vila Antônio'], dtype=object),
#        array(['Vila Aparecida'], dtype=object),
#        array(['Vila Araguaia'], dtype=object),
#        array(['Vila Arriete'], dtype=object),
#        array(['Vila Ayrosa'], dtype=object),
#        array(['Vila Bancária Munhoz'], dtype=object),
#        array(['Vila Barbosa'], dtype=object),
#        array(['Vila Bela'], dtype=object),
#        array(['Vila Bela Aliança'], dtype=object),
#        array(['Vila Bertioga'], dtype=object),
#        array(['Vila Boaçava'], dtype=object),
#        array(['Vila Brasilina'], dtype=object),
#        array(['Vila Brasílio Machado'], dtype=object),
#        array(['Vila Buenos Aires'], dtype=object),
#        array(['Vila Califórnia'], dtype=object),
#        array(['Vila Califórnia(Zona Sul)'], dtype=object),
#        array(['Vila Campo Grande'], dtype=object),
#        array(['Vila Canero'], dtype=object),
#        array(['Vila Caraguatá'], dtype=object),
#        array(['Vila Carbone'], dtype=object),
#        array(['Vila Cardoso Franco'], dtype=object),
#        array(['Vila Carmosina'], dtype=object),
#        array(['Vila Carrão'], dtype=object),
#        array(['Vila Clementino'], dtype=object),
#        array(['Vila Cláudia'], dtype=object),
#        array(['Vila Comercial'], dtype=object),
#        array(['Vila Conde do Pinhal'], dtype=object),
#        array(['Vila Congonhas'], dtype=object),
#        array(['Vila Constancia'], dtype=object),
#        array(['Vila Cordeiro'], dtype=object),
#        array(['Vila Cruzeiro'], dtype=object),
#        array(['Vila Curuçá'], dtype=object),
#        array(['Vila Darli'], dtype=object),
#        array(['Vila Dom Pedro I'], dtype=object),
#        array(['Vila ESão Pauloerança'], dtype=object),
#        array(['Vila Elvira'], dtype=object),
#        array(['Vila Ema'], dtype=object),
#        array(['Vila Ester (Zona Norte)'], dtype=object),
#        array(['Vila Firmiano Pinto'], dtype=object),
#        array(['Vila Formosa'], dtype=object),
#        array(['Vila Gea'], dtype=object),
#        array(['Vila Gertrudes'], dtype=object),
#        array(['Vila Gomes'], dtype=object),
#        array(['Vila Gomes Cardim'], dtype=object),
#        array(['Vila Guarani (Z Sul)'], dtype=object),
#        array(['Vila Guedes'], dtype=object),
#        array(['Vila Gumercindo'], dtype=object),
#        array(['Vila Gustavo'], dtype=object),
#        array(['Vila Ida'], dtype=object),
#        array(['Vila Império'], dtype=object),
#        array(['Vila Inah'], dtype=object),
#        array(['Vila Inglesa'], dtype=object),
#        array(['Vila Ipojuca'], dtype=object),
#        array(['Vila Isa'], dtype=object),
#        array(['Vila Ivg'], dtype=object),
#        array(['Vila Jacuí'], dtype=object),
#        array(['Vila Lageado'], dtype=object),
#        array(['Vila Leopoldina'], dtype=object),
#        array(['Vila Londrina'], dtype=object),
#        array(['Vila Lúcia'], dtype=object),
#        array(['Vila Macedópolis'], dtype=object),
#        array(['Vila Madalena'], dtype=object),
#        array(['Vila Mafra'], dtype=object),
#        array(['Vila Marari'], dtype=object),
#        array(['Vila Maria Alta'], dtype=object),
#        array(['Vila Mariana'], dtype=object),
#        array(['Vila Marieta'], dtype=object),
#        array(['Vila Mascote'], dtype=object),
#        array(['Vila Matilde'], dtype=object),
#        array(['Vila Mazzei'], dtype=object),
#        array(['Vila Medeiros'], dtype=object),
#        array(['Vila Mira'], dtype=object),
#        array(['Vila Moinho Velho'], dtype=object),
#        array(['Vila Monte Alegre'], dtype=object),
#        array(['Vila Monumento'], dtype=object),
#        array(['Vila Moraes'], dtype=object),
#        array(['Vila Morse'], dtype=object),
#        array(['Vila Morumbi'], dtype=object),
#        array(['Vila Nair'], dtype=object),
#        array(['Vila Nivi'], dtype=object),
#        array(['Vila Nova Caledonia'], dtype=object),
#        array(['Vila Nova Caledônia'], dtype=object),
#        array(['Vila Nova Conceição'], dtype=object),
#        array(['Vila Nova Curuçá'], dtype=object),
#        array(['Vila Nova Pauliceia'], dtype=object),
#        array(['Vila Olímpia'], dtype=object),
#        array(['Vila Oratório'], dtype=object),
#        array(['Vila Paiva'], dtype=object),
#        array(['Vila Palmeiras'], dtype=object),
#        array(['Vila Paulicéia'], dtype=object),
#        array(['Vila Paulista'], dtype=object),
#        array(['Vila Paulo Silas'], dtype=object),
#        array(['Vila Pedroso'], dtype=object),
#        array(['Vila Perus'], dtype=object),
#        array(['Vila Polopoli'], dtype=object),
#        array(['Vila Pompéia'], dtype=object),
#        array(['Vila Ponte Rasa'], dtype=object),
#        array(['Vila Prado'], dtype=object),
#        array(['Vila Primavera'], dtype=object),
#        array(['Vila Progredior'], dtype=object),
#        array(['Vila Prudente'], dtype=object),
#        array(['Vila Regente Feijó'], dtype=object),
#        array(['Vila Romana'], dtype=object),
#        array(['Vila Romano'], dtype=object),
#        array(['Vila Romero'], dtype=object),
#        array(['Vila Rui Barbosa'], dtype=object),
#        array(['Vila Ré'], dtype=object),
#        array(['Vila Sabrina'], dtype=object),
#        array(['Vila Salete'], dtype=object),
#        array(['Vila Santa Catarina'], dtype=object),
#        array(['Vila Santa Clara'], dtype=object),
#        array(['Vila Santa Maria'], dtype=object),
#        array(['Vila Santana'], dtype=object),
#        array(['Vila Santo Estéfano'], dtype=object),
#        array(['Vila Santos'], dtype=object),
#        array(['Vila Sao Paulo'], dtype=object),
#        array(['Vila Simone'], dtype=object),
#        array(['Vila Sonia'], dtype=object),
#        array(['Vila Suzana'], dtype=object),
#        array(['Vila São Francisco'], dtype=object),
#        array(['Vila São José (Ipiranga)'], dtype=object),
#        array(['Vila São Paulo'], dtype=object),
#        array(['Vila São Silvestre'], dtype=object),
#        array(['Vila Sílvia'], dtype=object),
#        array(['Vila Sônia'], dtype=object),
#        array(['Vila Talarico'], dtype=object),
#        array(['Vila Tiradentes'], dtype=object),
#        array(['Vila Tramontano'], dtype=object),
#        array(['Vila Vasconcelos'], dtype=object),
#        array(['Vila Vera'], dtype=object),
#        array(['Vila Virginia'], dtype=object),
#        array(['Vila da Saúde'], dtype=object),
#        array(['Vila das Belezas'], dtype=object),
#        array(['Vila das Mercês'], dtype=object),
#        array(['Vila do Encontro'], dtype=object),
#        array(['Água Branca'], dtype=object),
#        array(['Água Fria'], dtype=object),
#        array(['Água Funda'], dtype=object),
#        array(['Água Rasa'], dtype=object)], dtype=object)
